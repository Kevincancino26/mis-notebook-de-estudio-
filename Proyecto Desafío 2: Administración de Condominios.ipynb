# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevincancino26/mis-notebook-de-estudio-/blob/main/Proyecto%20Desaf%C3%ADo%202%3A%20Administraci%C3%B3n%20de%20Condominios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Proyecto Desafío 2: Administración de Condominios

# %% [markdown]
# para una guia mas detallada pudes consultar estos dos notebook
#
# curso: tratamiento y manipulacion de datos
# https://colab.research.google.com/drive/1GpuKnUrdNJGUF-Ozs65foX9Y1vzt2vnx#scrollTo=1atFeobssbhm
#
# proyecto desafio 1:Ventas online
# https://colab.research.google.com/github/Kevincancino26/mis-notebook-de-estudio-/blob/main/Proyecto%20Desafío%201%3A%20Ventas%20Online(Pandas_Tratamiento_manipulacion_de_datos).ipynb#scrollTo=qPCrpXAwhXaD

# %% [markdown]
# Administrar condominios es una tarea que requiere mucha atención y organización. Entre las diversas responsabilidades de gestión se encuentra el cobro del alquiler a los inquilinos. Para garantizar la buena salud financiera de la empresa, es fundamental que estos pagos se realicen de forma regular y puntual. Sin embargo, sabemos que esto no siempre sucede.
#
# Teniendo esto en cuenta, propongo un desafío de procesamiento de datos con el objetivo de analizar el retraso en el pago del alquiler en el condominio de algunos residentes. Pongo a disposición la base de datos dados_locacao_imoveis.json, que contiene información sobre el departamento de los inquilinos, el día acordado para el pago del alquiler, el día en que se realiza el pago del alquiler y el monto del alquiler.
#
# Con esta información, el desafío del proyecto 2: administración del condominio será similar al desafío del proyecto 1, abrir la base de datos con Pandas y aplicar json_normalize al DataFrame.

# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
url='https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_locacao_imoveis.json'

# %% [markdown]
# ###Preparar una cabecera para simular un navegador

# %%
# Agrega cabeceras para evitar el error 403
headers = {'User-Agent': 'Mozilla/5.0'}

# %%
response = requests.get(url, headers=headers)

# %%
# Si la respuesta fue exitosa (código 200)
if response.status_code == 200:
    data_json = response.json()
    datos_locacao_imoveis= pd.DataFrame(data_json)
    print(datos_locacao_imoveis.head())
else:
    print("Error al acceder a los datos:", response.status_code)
# Out:
#                                        dados_locacao
# 0  {'apartamento': 'A101 (blocoAP)', 'datas_combi...
# 1  {'apartamento': 'A102 (blocoAP)', 'datas_combi...
# 2  {'apartamento': 'B201 (blocoAP)', 'datas_combi...
# 3  {'apartamento': 'B202 (blocoAP)', 'datas_combi...
# 4  {'apartamento': 'C301 (blocoAP)', 'datas_combi...

# %%
datos_locacao_imoveis
# Out:
#                                         dados_locacao
# 0   {'apartamento': 'A101 (blocoAP)', 'datas_combi...
# 1   {'apartamento': 'A102 (blocoAP)', 'datas_combi...
# 2   {'apartamento': 'B201 (blocoAP)', 'datas_combi...
# 3   {'apartamento': 'B202 (blocoAP)', 'datas_combi...
# 4   {'apartamento': 'C301 (blocoAP)', 'datas_combi...
# 5   {'apartamento': 'C302 (blocoAP)', 'datas_combi...
# 6   {'apartamento': 'D401 (blocoAP)', 'datas_combi...
# 7   {'apartamento': 'D402 (blocoAP)', 'datas_combi...
# 8   {'apartamento': 'E501 (blocoAP)', 'datas_combi...
# 9   {'apartamento': 'E502 (blocoAP)', 'datas_combi...
# 10  {'apartamento': 'F601 (blocoAP)', 'datas_combi...
# 11  {'apartamento': 'F602 (blocoAP)', 'datas_combi...
# 12  {'apartamento': 'G701 (blocoAP)', 'datas_combi...
# 13  {'apartamento': 'G702 (blocoAP)', 'datas_combi...
# 14  {'apartamento': 'H801 (blocoAP)', 'datas_combi...

# %% [markdown]
# ####normalizando datos

# %%
datos_locacao_imoveis=pd.json_normalize(datos_locacao_imoveis['dados_locacao'])
datos_locacao_imoveis.head(10)
# Out:
#       apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0  A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1  A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2  B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3  B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4  C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
# 5  C302 (blocoAP)   [06/06/2022, 06/07/2022]  [08/06/2022, 12/07/2022]
# 6  D401 (blocoAP)   [07/06/2022, 07/07/2022]  [07/06/2022, 09/07/2022]
# 7  D402 (blocoAP)   [08/06/2022, 08/07/2022]  [10/06/2022, 14/07/2022]
# 8  E501 (blocoAP)   [09/06/2022, 09/07/2022]  [10/06/2022, 09/07/2022]
# 9  E502 (blocoAP)   [10/06/2022, 10/07/2022]  [16/06/2022, 12/07/2022]
#
#                       valor_aluguel
# 0  [$ 1000,0 reais, $ 2500,0 reais]
# 1  [$ 1100,0 reais, $ 2600,0 reais]
# 2  [$ 1200,0 reais, $ 2700,0 reais]
# 3  [$ 1300,0 reais, $ 2800,0 reais]
# 4  [$ 1400,0 reais, $ 2900,0 reais]
# 5  [$ 1500,0 reais, $ 1200,0 reais]
# 6  [$ 1600,0 reais, $ 1300,0 reais]
# 7  [$ 1700,0 reais, $ 1400,0 reais]
# 8  [$ 1800,0 reais, $ 1500,0 reais]
# 9  [$ 1900,0 reais, $ 1600,0 reais]

# %% [markdown]
# ##Etapa 2

# %% [markdown]
# Leímos la base de datos en el desafío anterior, ahora podemos seguir adelante con la transformación de estos datos. Entonces, de la misma manera que en el proyecto 1, el desafío del proyecto 2 está listado en algunas metas:
#
# Eliminar datos en listas dentro del DataFrame;
# Verificar tipos de datos;
# Identificar columnas numéricas;
# Transformar la columna numérica a tipo numérico.
